# %% [markdown]
# # 01 -

# %% [markdown]
# ## Libraries and paths

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import pandas as pd
import seaborn as sns
from scipy.stats import hypergeom
import sys
from pathlib import Path

project_root = Path().resolve().parent.parent
sys.path.append(str(project_root))
project_root

from src.mtg_mana.config import FIGURES_DIR, PROCESSED_DATA_DIR
from src.mtg_mana.layer_1_foundations.deck_parameters import params
from src.mtg_mana.layer_1_foundations.hypergeometric_baseline import land_prob
